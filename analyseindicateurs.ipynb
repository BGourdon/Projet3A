# %% [markdown]
# # Étude de l'évolution des indicateurs (en fonction des années, des scénarios et du niveau d'étude)

# %%
source("manipdatasets.R")

# %%
tracescenario("Baseline situation", "AF1", "WheatW", "Revenue" )
# Out:
# plot without title

# %%
tracescenario("Baseline situation", "arable", "WheatW", "Yield")
# Out:
# plot without title

# %%
tracescenario("")
