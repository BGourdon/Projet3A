# %% [markdown]
# # Étude de l'évolution des indicateurs (en fonction des années, des scénarios et du niveau d'étude)

# %%
source("manipdatasets.R")
# Out:
# Warning message:
# "package 'ggplot2' is in use and will not be installed"Warning message:
# "package 'tidyverse' is in use and will not be installed"

# %% [markdown]
# ### *Manipulation des différents datasets*

# %%
baselineAF1 <- fichierfarm("Baseline situation", "AF1", "Yield")

# %%
qplot(Year, Yield, data = baselineAF1) + facet_wrap(~ Crop)
# Out:
# plot without title
