# %% [markdown]
# # *Tracé des graphiques finaux pour les attributs de performance Energy Yield (EY) et Gross Margin (GM)*

# %% [markdown]
# ### 1. Création des datasets augmentés des calculs des métriques pour chaque PA

# %%
source("EY_GM.R") 
#code R contenant les fonctions de calculs de critères de dynamiques et de création des datasets par métrique pour EY et GM

# %%
EY_BLinefarm <- criteriadynamics_farm(dataEYfarm, "BLine", "EYfarm")

# %%
EY_BLineter <- criteriadynamics_ter(dataEYter, "BLine", "EYter")

# %%
EY_Synerfarm <- criteriadynamics_farm(dataEYfarm, "Syner", "EYfarm")

# %%
EY_Synerter <- criteriadynamics_ter(dataEYter, "Syner", "EYter")

# %%
GM_BLinefarm <- criteriadynamics_farm(dataGMfarm, "BLine", "GMfarm")

# %%
GM_BLineter <- criteriadynamics_ter(dataGMter, "BLine", "GMter")

# %%
GM_Synerfarm <- criteriadynamics_farm(dataGMfarm, "Syner", "GMfarm")

# %%
GM_Synerter <- criteriadynamics_ter(dataGMter, "Syner", "GMter")

# %%
# Exemple d'un dataset de sortie de la fonction criteriadynamics_farm
head(GM_Synerfarm)
# Out:
#   RCP    SSP  Mod   Year Farm Farm_group Area  PA3_GM    PA3_GM.level_Farm
# 1 RCP2.6 SSP1 Syner 2001 F1   AraF_Far   42.86  430.2016  434.4312
# 2 RCP2.6 SSP1 Syner 2001 F2   AraF_Far   64.43  404.6276  933.4188
# 3 RCP2.6 SSP1 Syner 2001 F3   LivS_Far   69.63 2469.7216 2956.6251
# 4 RCP2.6 SSP1 Syner 2001 F4   LivS_Far   65.68 3486.4677 3991.9032
# 5 RCP2.6 SSP1 Syner 2001 F5   AraF_Far   76.52 1032.3552 1364.8249
# 6 RCP2.6 SSP1 Syner 2001 F6   AraF_Far   65.11  763.7693  910.2419
#   PA3_GM.level_Group PA3_GM.TRENDf_Farm PA3_GM.TRENDf_Group PA3_GM.RSD_Farm
# 1 1002.451           -16.810196         -5.08373            92.65882
# 2 1002.451            -7.163537         -5.08373            69.44806
# 3 3474.264            16.691494         23.89507            23.34421
# 4 3474.264            31.098642         23.89507            16.93017
# 5 1002.451            -1.406912         -5.08373            82.89827
# 6 1002.451            -4.890620         -5.08373            35.32743
# ...

# %% [markdown]
# ### 2. Tracé des graphiques de comparaisons de scénarios pour un PA et une métrique donnés

# %% [markdown]
# #### 2.1_ Pour le PA Energy Yield EY

# %%
EYlevBL_f <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.level_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(20,70)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
EYlevSYN_f <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.level_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(20,70)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
EYlevBL_gp <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.level_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(30,65)) + facet_grid(.~RCP) 
EYlevSYN_gp <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.level_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(30,65)) + facet_grid(.~RCP)

EYtrendBL_f <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.TRENDf_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-0.02,0.02)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
EYtrendSYN_f <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.TRENDf_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-0.02,0.02)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
EYtrendBL_gp <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.TRENDf_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-0.006,0.006)) + facet_grid(.~RCP)
EYtrendSYN_gp <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.TRENDf_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-0.006,0.006)) + facet_grid(.~RCP)

EYRSDBL_f <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.RSD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,30))  + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
EYRSDSYN_f  <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.RSD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,30))  + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
EYRSDBL_gp <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.RSD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(6,9))  + facet_grid(.~RCP)
EYRSDSYN_gp <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.RSD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(6,9))  + facet_grid(.~RCP)
 
EYSSRBL_f <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.SSR_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,4.5)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
EYSSRSYN_f <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.SSR_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,4.5)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
EYSSRBL_gp <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.SSR_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,2)) + facet_grid(.~RCP)
EYSSRSYN_gp <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.SSR_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,2)) + facet_grid(.~RCP)

EYNODBL_f <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.NOD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,12.5)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
EYNODSYN_f <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.NOD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,12.5)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
EYNODBL_gp <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.NOD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-0.02,0.02)) + facet_grid(.~RCP)
EYNODSYN_gp <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.NOD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-0.02,0.02)) + facet_grid(.~RCP)

EYprobahighBL_f <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.probahigh_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0.8,1)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
EYprobahighSYN_f <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.probahigh_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0.8,1)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
EYprobahighBL_gp <- ggplot(EY_BLinefarm) + geom_point(aes(x=SSP, y=PA1_EY.probahigh_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0.7,1)) + facet_grid(.~RCP)
EYprobahighSYN_gp <- ggplot(EY_Synerfarm) + geom_point(aes(x=SSP, y=PA1_EY.probahigh_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0.7,1)) + facet_grid(.~RCP)

# %%
install.packages("gridExtra")
install.packages("grid")
library("gridExtra")
library("grid")

# %%
EY_level <- grid.arrange(EYlevBL_f, EYlevSYN_f, EYlevBL_gp, EYlevSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique Level pour EY")
ggsave("EY_level.png", plot = EY_level, width = 11, height = 8)
# Out:
# plot without title

# %%
EY_trend <- grid.arrange(EYtrendBL_f, EYtrendSYN_f, EYtrendBL_gp, EYtrendSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique Trend pour EY")
ggsave("EY_trend.png", plot = EY_trend, width = 11, height = 8)
# Out:
# plot without title

# %%
EY_RSD <- grid.arrange(EYRSDBL_f, EYRSDSYN_f , EYRSDBL_gp, EYRSDSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique RSD pour EY")
ggsave("EY_RSD.png", plot = EY_RSD, width = 11, height = 8)
# Out:
# plot without title

# %%
EY_NOD <- grid.arrange(EYNODBL_f, EYNODSYN_f, EYNODBL_gp, EYNODSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique NOD pour EY")
ggsave("EY_NOD.png", plot = EY_NOD, width = 11, height = 8)
# Out:
# plot without title

# %% [markdown]
# #### 2.2_ Pour le PA Gross Margin GM

# %%
GMlevBL_f <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.level_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,5000)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
GMlevSYN_f <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.level_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,5000)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
GMlevBL_gp <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.level_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,4000)) + facet_grid(.~RCP) 
GMlevSYN_gp <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.level_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,4000)) + facet_grid(.~RCP)

GMtrendBL_f <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.TRENDf_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-25,75)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
GMtrendSYN_f <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.TRENDf_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-25,75)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
GMtrendBL_gp <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.TRENDf_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-20,60)) + facet_grid(.~RCP)
GMtrendSYN_gp <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.TRENDf_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(-20,60)) + facet_grid(.~RCP)

GMRSDBL_f <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.RSD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,150)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
GMRSDSYN_f  <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.RSD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,150)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
GMRSDBL_gp <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.RSD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,65)) + facet_grid(.~RCP)
GMRSDSYN_gp <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.RSD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,65)) + facet_grid(.~RCP)
 
GMSSRBL_f <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.SSR_Farm, color=Farm)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
GMSSRSYN_f <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.SSR_Farm, color=Farm)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
GMSSRBL_gp <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.SSR_Group, color=Farm_group)) + facet_grid(.~RCP)
GMSSRSYN_gp <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.SSR_Group, color=Farm_group)) + facet_grid(.~RCP)

GMNODBL_f <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.NOD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,35)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
GMNODSYN_f <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.NOD_Farm, color=Farm)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,35)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
GMNODBL_gp <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.NOD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,35)) + facet_grid(.~RCP)
GMNODSYN_gp <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.NOD_Group, color=Farm_group)) + scale_x_discrete(labels=c("SSP1" = "1", "SSP2" = "2",
                              "SSP3" = "3")) + scale_y_continuous(limits = c(0,35)) + facet_grid(.~RCP)

GMprobahighBL_f <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.probahigh_Farm, color=Farm)) + facet_grid(.~RCP) + ggtitle("Baseline") + theme(plot.title = element_text(hjust = 0.5))
GMprobahighSYN_f <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.probahigh_Farm, color=Farm)) + facet_grid(.~RCP) + ggtitle("Synergetic") + theme(plot.title = element_text(hjust = 0.5))
GMprobahighBL_gp <- ggplot(GM_BLinefarm) + geom_point(aes(x=SSP, y=PA3_GM.probahigh_Group, color=Farm_group)) + facet_grid(.~RCP)
GMprobahighSYN_gp <- ggplot(GM_Synerfarm) + geom_point(aes(x=SSP, y=PA3_GM.probahigh_Group, color=Farm_group)) + facet_grid(.~RCP)

# %%
GM_level <- grid.arrange(GMlevBL_f, GMlevSYN_f, GMlevBL_gp, GMlevSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique Level pour GM")
ggsave("GM_level.png", plot = GM_level, width = 11, height = 8)
# Out:
# plot without title

# %%
GM_trend <- grid.arrange(GMtrendBL_f, GMtrendSYN_f, GMtrendBL_gp, GMtrendSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique Trend pour GM")
ggsave("GM_trend.png", plot = GM_trend, width = 11, height = 8)
# Out:
# plot without title

# %%
GM_RSD <- grid.arrange(GMRSDBL_f, GMRSDSYN_f , GMRSDBL_gp, GMRSDSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique RSD pour GM")
ggsave("GM_RSD.png", plot = GM_RSD, width = 11, height = 8)
# Out:
# plot without title

# %%
GM_NOD <- grid.arrange(GMNODBL_f, GMNODSYN_f, GMNODBL_gp, GMNODSYN_gp, ncol=2, nrow = 2, top = "Évolution de la métrique NOD pour GM")
ggsave("GM_NOD.png", plot = GM_NOD, width = 11, height = 8)
# Out:
# plot without title

# %% [markdown]
# ### 3. Tracé des graphiques de comparaison de la résilience dans les modalités Baseline et Synergetic

# %% [markdown]
# #### 3.1_ Pour le PA Energy Yield EY

# %%
EYlevBL <- table(EY_BLinefarm, EY_BLineter, "BLine", "level")
EYlevSYN <- table(EY_Synerfarm, EY_Synerter, "Syner", "level")

EYtrendBL <- table(EY_BLinefarm, EY_BLineter, "BLine", "TRENDf")
EYtrendSYN <- table(EY_Synerfarm, EY_Synerter, "Syner", "TRENDf")

EYRSDBL <- table(EY_BLinefarm, EY_BLineter, "BLine", "RSD")
EYRSDSYN <- table(EY_Synerfarm, EY_Synerter, "Syner", "RSD")

EYNODBL <- table(EY_BLinefarm, EY_BLineter, "BLine", "NOD")
EYNODSYN <- table(EY_Synerfarm, EY_Synerter, "Syner", "NOD")

# %%
# exemple de dataset de sortie de la fonction table
head(GMlevBL)
# Out:
#    SSP1RCP26 SSP2RCP26 SSP3RCP26 SSP1RCP45 SSP2RCP45 SSP3RCP45 SSP1RCP85
# F1  418.6745  324.9120  564.8643  418.6745  324.9120  564.8643  418.6745
# F2  789.0636  676.0172  974.3200  788.7948  675.8048  974.0957  789.3595
# F3 2792.4524 2488.2839 3165.7498 2792.4792 2488.3121 3165.7724 2792.4381
# F4 4099.4788 3682.7022 4577.4605 4099.4785 3682.7020 4577.4601 4099.4798
# F5 1240.8550 1111.2701 1438.7947 1240.8550 1111.2701 1438.7947 1240.8550
# F6  671.5836  563.6039  841.2387  671.1048  563.1593  840.7045  671.8127
#    SSP2RCP85 SSP3RCP85
# F1  324.9120  564.8643
# F2  676.3000  974.6270
# F3 2488.2723 3165.7206
# F4 3682.7032 4577.4615
# F5 1111.2701 1438.7947
# F6  563.8041  841.5033

# %%
sousEYlev <- EYlevSYN - EYlevBL
Type <- rownames(sousEYlev)
newsousEYlev <- cbind(Type, data.frame(sousEYlev))
newsousEYlev$Type <- as.character(newsousEYlev$Type)
newsousEYlev$Type <- factor(newsousEYlev$Type, levels=unique(newsousEYlev$Type))
meltsousEYlev <- melt(newsousEYlev, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
EYlev_res <- ggplot(meltsousEYlev, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red", "orange", "green", "darkgreen"), limits = c(-10, 10))
ggsave("EYlevel_resilience.png", plot = EYlev_res, width = 11, height = 8)
EYlev_res
# Out:
# plot without title

# %%
sousEYtrend <- EYtrendSYN - EYtrendBL
Type <- rownames(sousEYtrend)
newsousEYtrend <- cbind(Type, data.frame(sousEYtrend))
newsousEYtrend$Type <- as.character(newsousEYtrend$Type)
newsousEYtrend$Type <- factor(newsousEYtrend$Type, levels=unique(newsousEYtrend$Type))
#newsousEYtrend
meltsousEYtrend <-  melt(newsousEYtrend, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
EYtrend_res <- ggplot(meltsousEYtrend, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red", "orange", "green", "darkgreen"), limits = c(-0.02, 0.02))
EYtrend_res
ggsave("EYtrend_resilience.png", plot = EYtrend_res, width = 11, height = 8)
# Out:
# plot without title

# %%
sousEYRSD <- EYRSDBL - EYRSDSYN #plus la différence est positive, plus on a diminué la variabilité dans la modalité Synergetic
#pb : ne prend pas en compte/ne permet pas de voir le niveau de variabilité dans les deux modalités (on veut qu'elle se rapproche de 0, ne permet pas de voir ça)
Type <- rownames(sousEYRSD)
newsousEYRSD <- cbind(Type, data.frame(sousEYRSD))
newsousEYRSD$Type <- as.character(newsousEYRSD$Type)
newsousEYRSD$Type <- factor(newsousEYRSD$Type, levels=unique(newsousEYRSD$Type))
#newsousEYRSD
meltsousEYRSD <-  melt(newsousEYRSD, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
EYRSD_res <- ggplot(meltsousEYRSD, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red", "orange", "yellow", "green"), limits = c(-16, 5))
EYRSD_res
ggsave("EYRSD_resilience.png", plot = EYRSD_res, width = 11, height = 8)
# Out:
# plot without title

# %%
sousEYNOD <- EYNODBL - EYNODSYN #plus la différence est positive, plus on a diminué le NOD dans la modalité Synergetic
#pb : ne prend pas en compte/ne permet pas de voir le niveau de NOD dans les deux modalités (on veut qu'elle se rapproche de 0, ne permet pas de voir ça)
Type <- rownames(sousEYNOD)
newsousEYNOD <- cbind(Type, data.frame(sousEYNOD))
newsousEYNOD$Type <- as.character(newsousEYNOD$Type)
newsousEYNOD$Type <- factor(newsousEYNOD$Type, levels=unique(newsousEYNOD$Type))
#newsousEYNOD
meltsousEYNOD <-  melt(newsousEYNOD, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
EYNOD_res <- ggplot(meltsousEYNOD, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red","green"), limits = c(-12, 0))
EYNOD_res
ggsave("EYNOD_resilience.png", plot = EYNOD_res, width = 11, height = 8)
# Out:
# plot without title

# %% [markdown]
# #### 3.2_ Pour le PA Gross Margin GM

# %%
GMlevBL <- table(GM_BLinefarm, GM_BLineter, "BLine", "level")
GMlevSYN <- table(GM_Synerfarm, GM_Synerter, "Syner", "level")

GMtrendBL <- table(GM_BLinefarm, GM_BLineter, "BLine", "TRENDf")
GMtrendSYN <- table(GM_Synerfarm, GM_Synerter, "Syner", "TRENDf")

GMRSDBL <- table(GM_BLinefarm, GM_BLineter, "BLine", "RSD")
GMRSDSYN <- table(GM_Synerfarm, GM_Synerter, "Syner", "RSD")

GMNODBL <- table(GM_BLinefarm, GM_BLineter, "BLine", "NOD")
GMNODSYN <- table(GM_Synerfarm, GM_Synerter, "Syner", "NOD")

# %%
sousGMlev <- GMlevSYN - GMlevBL
Type <- rownames(sousGMlev)
newsousGMlev <- cbind(Type, data.frame(sousGMlev))
newsousGMlev$Type <- as.character(newsousGMlev$Type)
newsousGMlev$Type <- factor(newsousGMlev$Type, levels=unique(newsousGMlev$Type))
#newsousGMlev
meltsousGMlev <- melt(newsousGMlev, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
GMlev_res <- ggplot(meltsousGMlev, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red", "orange", "green", "darkgreen"), limits = c(-120, 250))
ggsave("GMlevel_resilience.png", plot = GMlev_res, width = 11, height = 8)
GMlev_res
# Out:
# plot without title

# %%
sousGMtrend <- GMtrendSYN - GMtrendBL
Type <- rownames(sousGMtrend)
newsousGMtrend <- cbind(Type, data.frame(sousGMtrend))
#newsousGMtrend
newsousGMtrend$Type <- as.character(newsousGMtrend$Type)
newsousGMtrend$Type <- factor(newsousGMtrend$Type, levels=unique(newsousGMtrend$Type))
meltsousGMtrend <-  melt(newsousGMtrend, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
GMtrend_res <- ggplot(meltsousGMtrend, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red", "orange", "green", "darkgreen"), limits = c(-4, 8))
GMtrend_res
ggsave("GMtrend_resilience.png", plot = GMtrend_res, width = 11, height = 8)
# Out:
# plot without title

# %%
sousGMRSD <- GMRSDBL - GMRSDSYN #plus la différence est positive, plus on a diminué la variabilité dans la modalité Synergetic
#pb : ne prend pas en compte/ne permet pas de voir le niveau de variabilité dans les deux modalités (on veut qu'elle se rapproche de 0, ne permet pas de voir ça)
Type <- rownames(sousGMRSD)
newsousGMRSD <- cbind(Type, data.frame(sousGMRSD))
newsousGMRSD$Type <- as.character(newsousGMRSD$Type)
newsousGMRSD$Type <- factor(newsousGMRSD$Type, levels=unique(newsousGMRSD$Type))
#newsousGMRSD
meltsousGMRSD <-  melt(newsousGMRSD, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
GMRSD_res <- ggplot(meltsousGMRSD, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red", "orange", "yellow", "green"), limits = c(-36, 38))
GMRSD_res
ggsave("GMRSD_resilience.png", plot = GMRSD_res, width = 11, height = 8)
# Out:
# plot without title

# %%
sousGMNOD <- GMNODBL - GMNODSYN #plus la différence est positive, plus on a diminué le NOD dans la modalité Synergetic
#pb : ne prend pas en compte/ne permet pas de voir le niveau de NOD dans les deux modalités (on veut qu'elle se rapproche de 0, ne permet pas de voir ça)
Type <- rownames(sousGMNOD)
newsousGMNOD <- cbind(Type, data.frame(sousGMNOD))
newsousGMNOD$Type <- as.character(newsousGMNOD$Type)
newsousGMNOD$Type <- factor(newsousGMNOD$Type, levels=unique(newsousGMNOD$Type))
#newsousGMNOD
meltsousGMNOD <-  melt(newsousGMNOD, id.vars = "Type", measure.vars = c("SSP1RCP26", "SSP2RCP26", "SSP3RCP26", "SSP1RCP45", "SSP3RCP45", "SSP1RCP85", "SSP2RCP85", "SSP3RCP85"), variable.name = "Scenario", value.name = "Valeur")
GMNOD_res <- ggplot(meltsousGMNOD, aes(Scenario, Type, fill = Valeur)) + geom_raster(hjust = 0, vjust = 0) + scale_x_discrete(labels=c("SSP1RCP26" = "1_2.6", "SSP2RCP26" = "2_2.6","SSP3RCP26" = "3_2.6", "SSP1RCP45" = "1_4.5", "SSP2RCP45" = "2_4.5", "SSP3RCP45" = "3_4.5", "SSP1RCP85" = "1_8.5", "SSP2RCP85" = "2_8.5", "SSP3RCP85" = "3_8.5")) + scale_fill_gradientn(name = "Valeur", colours = c("red","green"), limits = c(-12, 12))
GMNOD_res
ggsave("GMNOD_resilience.png", plot = GMNOD_res, width = 11, height = 8)
# Out:
# plot without title
